# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Subsetting and Modifying Data📍 📍</h1></center>
#
#
# ---
#
#
# #### `READ THE BIG MART SALES DATA`
#
#
# ---

# %%
import pandas as pd

# %%
data = pd.read_csv('Downloads/delete/dataset/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ---
#
# #### `Select the rows where Item_MRP is less than 100`
#
#
# ---

# %%
# WRITE YOUR CODE HERE
data[data['Item_MRP'] < 100] ['Item_MRP']
# Out:
# 1       48.2692
# 4       53.8614
# 5       51.4008
# 6       57.6588
# 8       96.9726
#          ...
# 8513    99.9042
# 8514    57.5904
# 8516    58.7588
# 8520    85.1224
# 8522    75.4670
# Name: Item_MRP, Length: 2439, dtype: float64

# %%
data.loc[data.Item_MRP < 100]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# ...

# %% [markdown]
# ---
#
# #### `Select the rows where Outlet_Location_Type is Tier 1 and Outlet_Establishment_Year is from the list [1987, 1988, 2009]`
#
# ---

# %%
# WRITE YOUR CODE HERE
#data.loc[data.Outlet_Establishment_Year == 1987]
data.loc[(data.Outlet_Establishment_Year == 1987)|(data.Outlet_Establishment_Year == 1988)|(data.Outlet_Establishment_Year == 2009) & (data.Outlet_Location_Type == 'Tier 1')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# ...

# %%
data.loc[(data.Outlet_Location_Type == 'Tier 1')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 2              FDN15        17.50          Low Fat         0.016760
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8490           FDU44          NaN          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ---
#
# #### `Update the values of the column Outlet_Type using the mapping given below`
#
#
# ---

# %%
mapping: {
    'Supermarket Type1' : 1,
    'Supermarket Type2' : 2,
    'Grocery Store'     : 3,
    'Supermarket Type3' : 4
}

# %%
# WRITE YOUR CODE HERE
data.Outlet_Type.map(mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 # WRITE YOUR CODE HERE
# ----> 2 data.Outlet_Type.map(mapping)
#
# NameError: name 'mapping' is not defined

# %% [markdown]
# ---
#
# #### `Fill the missing values in the column 'Outlet_Size' by Medium using loc`
#
# ---

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.loc[data.Outlet_Size.isna() == True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
# WRITE YOUR CODE HERE
data.loc[(data.Outlet_Size.isna() == True) , 'Outlet_Size'] = 'Medium'

# %%
data.Outlet_Size.fillna('Medium', inplace=True)

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...
